# %% [markdown]
# <a href="https://colab.research.google.com/github/rajmayukh78/aws-ml-engineeering-task/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d={'name':'raj','age':20,'roll':1234}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'roll'])

# %%
for i in d.keys():
  print(i)
# Out:
# name
# age
# roll

# %%
for i in d.keys():
  print(d[i])
# Out:
# raj
# 20
# 1234

# %%
def hello():
  print("hello function")

# %%
hello()
# Out:
# hello function

# %%
def name(a):
  print(a)

# %%
name("raj")
# Out:
# raj

# %%
def name(a,b):
   print(a,b)

# %%
name("raj","minu")
# Out:
# raj minu
